# %% [markdown]
# # 集合的访问与管理

# %%
import os; nb_dir = os.getcwd(); 
import sys; 
sys.path.append(
    os.sep.join([nb_dir, os.pardir, os.pardir, "Customized_Package"])
);

# %%
import ipynb_quick_render

# %%
S1 = {2, 3, 5, 7, 11};

# %% [markdown]
# ## 集合与字典的异同
# 集合内的元素, 以及字典的键, 均具有互异性和无序性;
#
# 但集合内的元素无法被索引, 字典的键值对可以通过键名进行索引.

# %%
print({1} == {1, 1}, {1, 2} == {2, 1}); 
try: 
    print(S1[0])
except Exception as err: 
    print(type(err), str(err));
# Out:
# True True
# <class 'TypeError'> 'set' object is not subscriptable

# %% [markdown]
# ## 用`generator`对象检索集合中的内容

# %% [markdown]
# ### 按一定条件检索集合中的元素, 使得符合条件的检索结果应用变换, 变换结果构成子集

# %%
print({x for x in S1 if x < 10}) #描述法构建子集. 
print({(x, y) for x in S1 for y in S1}) #笛卡尔积.
# Out:
# {2, 3, 5, 7}
# {(7, 3), (11, 11), (11, 2), (3, 11), (7, 7), (3, 7), (2, 5), (7, 11), (7, 2), (3, 3), (5, 5), (11, 5), (2, 2), (3, 2), (5, 11), (7, 5), (2, 3), (5, 3), (2, 7), (3, 5), (11, 7), (5, 7), (2, 11), (11, 3), (5, 2)}

# %% [markdown]
# ## 集合中计数信息的查询
# * 查询集合的基数: `len(s)`或`s.__len__()`
# * 查询一个元素在集合中...
#     * ...是否存在: `elem in s`或`s.__contains__(elem)`

# %%
print(S1)
print(len(S1))
num = range(0, 11, 1); 
ipynb_quick_render.Table2d(
    [list(num), list(int(x in S1) for x in range(0, 11, 1))]
).render();
# Out:
# {2, 3, 5, 7, 11}
# 5
# <table><tr><td>0</td><td>1</td><td>2</td><td>3</td><td>4</td><td>5</td><td>6</td><td>7</td><td>8</td><td>9</td><td>10</td></tr><tr><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><table>

# %% [markdown]
# ## 集合的运算
#
# `set`对象支持的运算类型与数学中的集合运算相同, 每种运算均有两种方法, 分别提供不同的功能:
#
# |运算类型|仅返回运算结果<br>且不改变原`set`对象|修改对应的`set`对象的功能<br>(返回值为`None`)|
# |:-:|:-|:-|
# |并|`union`|`update`|
# |交|`intersection`|`intersection_update`|
# |差|`difference`|`difference_update`|
# |对称差|`symmetric_difference`|`symmetric_difference_update`|

# %%
S2 = set(range(1, 10, 2)); 
props = ["union", "intersection", "difference", "symmetric_difference"]; 
S3 = [S1.__getattribute__(prop)(S2) for prop in props]; 
ipynb_quick_render.Table2d(
    list(zip(["S1", "S2"] + props, [S1, S2] + S3))
).render();
# Out:
# <table><tr><td>S1</td><td>{2, 3, 5, 7, 11}</td></tr><tr><td>S2</td><td>{1, 3, 5, 7, 9}</td></tr><tr><td>union</td><td>{1, 2, 3, 5, 7, 9, 11}</td></tr><tr><td>intersection</td><td>{3, 5, 7}</td></tr><tr><td>difference</td><td>{2, 11}</td></tr><tr><td>symmetric_difference</td><td>{1, 2, 9, 11}</td></tr><table>

# %% [markdown]
# ## 集合的结构编辑
# 以下方法若通过集合**所挂载变量直接调用**, 会直接**修改对应的`set`对象**. \
# 若只需要用一个变量链接到编辑结果, 但**不修改起初被访问的集合**, 需要先调用`copy()`方法.
#
# * `s.add(elem)` 向集合`s`中添加元素`elem`;
# * `s.remove(elem)` 从集合`s`中移除元素`elem`, 若该元素在移除前不存在, 抛出`KeyError`.
#
# 由于`set`内元素的无序性, 因此, 很多与**元素顺序**有关的方法**只适用于`list`, 不适用于`set`**.

# %%
S1_dupli = S1.copy()
print(S1_dupli.add(0)); 
print(S1_dupli); 
print(S1_dupli.add(1)); 
print(S1_dupli); 
print([key for key in S1]); 
[print(S1_dupli.remove(elem), hex(id(S1_dupli)), len(S1_dupli)) for elem in S1]; 
print(S1_dupli);
# Out:
# None
# {0, 2, 3, 5, 7, 11}
# None
# {0, 1, 2, 3, 5, 7, 11}
# [2, 3, 5, 7, 11]
# None 0x54904a8 6
# None 0x54904a8 5
# None 0x54904a8 4
# None 0x54904a8 3
# None 0x54904a8 2
# {0, 1}
